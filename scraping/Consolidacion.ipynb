# %%
import pandas as pd
import numpy as np

# %%
wom_1 = pd.read_csv('')
wom_2 = pd.read_csv('')

display(wom_1.head())
# Out:
#   operadora                               producto   marca  precio_prepago  \
# 0       WOM             Redmi Note 12 Pro 5G Black  Xiaomi          228000
# 1       WOM              Redmi Note 12 Pro 5G Blue  Xiaomi          228000
# 2       WOM             Redmi Note 12 Pro 5G White  Xiaomi          228000
# 3       WOM  Apple iPhone Air 5G 512GB Space Black   Apple         1480800
# 4       WOM        ZTE Blade A56 Pro 4G 128GB Grey     ZTE          115200
#
#    precio_portabilidad/renovacion  precio_normal  precio_linea_nueva  \
# 0                          204000       459990.0              204000
# 1                          204000       459990.0              204000
# 2                          204000       459990.0              204000
# 3                         1360800      1559990.0             1360800
# 4                          103200       149990.0              103200
#
#    cuota_arriendo           sku fecha_extraccion
# 0         16000.0  001.002.2376       2026-05-13
# ...

# %%
wom_total = pd.concat([wom_1, wom_2], ignore_index=True)

print(f'Filas en wom_1: {len(wom_1)}')
print(f'Filas en wom_2: {len(wom_2)}')
print(f'Total de filas después de unir: {len(wom_total)}')

display(wom_total.tail())
# Out:
# Filas en wom_1: 482
# Filas en wom_2: 120
# Total de filas después de unir: 602
#     operadora                                  producto   marca  \
# 597       WOM  Redmi Note 15 Pro 5G 512GB Bundle Silver  Xiaomi
# 598       WOM          Redmi Note 15 Pro 5G 512GB Black  Xiaomi
# 599       WOM         Redmi Note 15 Pro 5G 512GB Silver  Xiaomi
# 600       WOM           Apple iPhone 17e 5G 256GB Black   Apple
# 601       WOM       Apple iPhone 17e 5G 256GB Soft Pink   Apple
#
#      precio_prepago  precio_portabilidad/renovacion  precio_normal  \
# 597          376800                          340800       449990.0
# 598          376800                          340800       449990.0
# 599          376800                          340800       449990.0
# 600          660000                          660000       699990.0
# 601          660000                          660000       699990.0
#
#      precio_linea_nueva  cuota_arriendo           sku fecha_extraccion
# ...

# %%
wom_total.to_csv('wom_consolidado.csv', index=False)
print('Archivo exportado exitosamente')
# Out:
# Archivo exportado exitosamente como wom_total_unido.csv
